# %%
#chef and chefina rolling a dice
import numpy as np
dice =[1,2,3,4,5,6]
x = np.random.choice(dice)
y = np.random.choice(dice)

z= x + y
print(x,'+',y,'=',z)
if  z < 6 :
  print('The Turn is not good')
else:
  print('The Turn is good')
# Out:
# 6 + 2 = 8
# The Turn is good
