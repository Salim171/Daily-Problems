# %%
#defied if user is boy or girl using thire name characters num in odd is boy otherwise its girl
num = int(input('Enter The number of characters : '))

if num % 2 == 0 :
    print("The user is Girl")
else:
    print("The user is Boy")
# Out:
# Enter The number of characters : 6
# The user is Girl
