# %%
# print the highest number of 5 numbers
l1=[]
for i in range (5):
    n=int(input(f"Enter the number: "))
    l1.append(n)
print("the highest number is",max(l1))
# Out:
# Enter the number: 1
# Enter the number: 2
# Enter the number: 3
# the highest number is 3
